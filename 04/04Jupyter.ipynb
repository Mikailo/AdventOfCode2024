# %%
import os
import pandas as pd
import numpy as np
import re

# %%
# f = open("inputFile", "r")
f = open("wak_input.txt", "r")

# print(f.read())

wholeInput = f.read()

wholeInput = wholeInput.replace('\n', '')
# print(wholeInput.replace('n', ''))

# %%
len(wholeInput)
# Out:
# 19600

# %%
# Straight
x = re.findall("XMAS", wholeInput) 
# print(x)

num_straight = len(x)
# print(num_straight)

#Straight
straight_counter = 0
for it, letter in enumerate(wholeInput):
    if letter == "X":
        if (it+1) < 19600 and (it)%140 < (it+1)%140 and wholeInput[it+1] == "M":
            if (it+2) < 19600 and (it)%140 < (it+2)%140 and wholeInput[it+2] == "A":
                if (it+3) < 19600 and (it)%140 < (it+3)%140 and wholeInput[it+3] == "S" :
                    straight_counter = straight_counter +1 
                    
print(straight_counter)
# Out:
# 212

# %%
# # Straight Reverse

#Straight Reverse
straight_counter_reverse = 0
for it, letter in enumerate(wholeInput):
    if letter == "S":
        if (it+1) < 19600 and (it)%140 < (it+1)%140 and wholeInput[it+1] == "A":
            if (it+2) < 19600 and (it)%140 < (it+2)%140 and wholeInput[it+2] == "M":
                if (it+3) < 19600 and (it)%140 < (it+3)%140 and wholeInput[it+3] == "X" :
                    straight_counter_reverse = straight_counter_reverse +1 

print(straight_counter_reverse)
# x = re.findall("SAMX", wholeInput) 
# print(x)
# 
# num_straight_reverse = len(x)
# print(num_straight_reverse)
# Out:
# 221

# %%
#Vertical
vertical_counter = 0
for it, letter in enumerate(wholeInput):
    if letter == "X" and (it+140) < 19600:
        if (it+140) < 19600 and wholeInput[it+140] == "M":
            if (it+140+140) < 19600 and wholeInput[it+140+140] == "A":
                if (it+140+140+140) < 19600 and wholeInput[it+140+140+140] == "S" :
                    vertical_counter = vertical_counter +1 
                    
print(vertical_counter)
# Out:
# 201

# %%
#Vertical Reverse
vertical_counter_reverse = 0
for it, letter in enumerate(wholeInput):
    if letter == "S" and (it+140) < 19600:
        if (it+140) < 19600 and wholeInput[it+140] == "A":
            if (it+140+140) < 19600 and wholeInput[it+140+140] == "M":
                if (it+140+140+140) < 19600 and wholeInput[it+140+140+140] == "X" :
                    vertical_counter_reverse = vertical_counter_reverse +1 
                    
print(vertical_counter_reverse)
# Out:
# 238

# %%
#Diagonal Right
diagonal_counter_right= 0
for it, letter in enumerate(wholeInput):
    if letter == "X" and (it+140) < 19600:
        if (it+141) < 19600 and (it+140)%140 < (it+141)%140 and wholeInput[it+141] == "M":
            if (it+141+141) < 19600 and (it+140+140)%140 < (it+141+141)%140 and wholeInput[it+141+141] == "A":
                if (it+141+141+141) < 19600 and (it+140+140+140)%140 < (it+141+141+141)%140 and wholeInput[it+141+141+141] == "S" :
                    diagonal_counter_right = diagonal_counter_right +1 
                    
print(diagonal_counter_right)
# Out:
# 398

# %%
#Diagonal Left
diagonal_counter_left= 0
for it, letter in enumerate(wholeInput):
    if letter == "X" and (it+140) < 19600:
        if (it+139) < 19600 and (it+140)%140 > (it+139)%140 and wholeInput[it+139] == "M":
            if (it+139+139) < 19600 and (it+140+140)%140 > (it+139+139)%140 and wholeInput[it+139+139] == "A":
                if (it+139+139+139) < 19600 and (it+140+140+140)%140 > (it+139+139+139)%140 and wholeInput[it+139+139+139] == "S" :
                    diagonal_counter_left = diagonal_counter_left +1 
        
                    
print(diagonal_counter_left)
# Out:
# 422

# %%
#Diagonal Right Reverse
diagonal_counter_right_reverse= 0
for it, letter in enumerate(wholeInput):
    if letter == "S" and (it+140) < 19600:
        if (it+141) < 19600 and (it+140)%140 < (it+141)%140 and wholeInput[it+141] == "A":
            if (it+141+141) < 19600 and (it+140+140)%140 < (it+141+141)%140 and wholeInput[it+141+141] == "M":
                if (it+141+141+141) < 19600 and (it+140+140+140)%140 < (it+141+141+141)%140 and wholeInput[it+141+141+141] == "X" :
                    diagonal_counter_right_reverse = diagonal_counter_right_reverse +1 
                    
print(diagonal_counter_right_reverse)
# Out:
# 451

# %%
#Diagonal Left Reverse
diagonal_counter_left_reverse= 0
for it, letter in enumerate(wholeInput):
    if letter == "S" and (it+140) < 19600:
        if (it+139) < 19600 and (it+140)%140 > (it+139)%140 and wholeInput[it+139] == "A":
            if (it+139+139) < 19600 and (it+140+140)%140 > (it+139+139)%140 and wholeInput[it+139+139] == "M":
                if (it+139+139+139) < 19600 and (it+140+140+140)%140 > (it+139+139+139)%140 and wholeInput[it+139+139+139] == "X" :
                    diagonal_counter_left_reverse = diagonal_counter_left_reverse +1 
                    
print(diagonal_counter_left_reverse)
# Out:
# 435

# %%
Total = straight_counter+ straight_counter_reverse + vertical_counter + vertical_counter_reverse + diagonal_counter_right + diagonal_counter_left + diagonal_counter_right_reverse + diagonal_counter_left_reverse

# %%
print(Total)
# Out:
# 2578

# %%
19739/140
# Out:
# 140.99285714285713

# %%
test = "XMASMXMXMAXSMMSSSSXSXMASMSAXMAXAXXMASASMSXSSSSSMMXSXMASASMSMMXSASASXXXXSMSXSMSXMASXXMASMMASXMXSXMSMMMMMSXXMASASMSSSSSMMSMMSSMSMSSMXSAMMSMMMM"
len(test)
# Out:
# 140

# %%
140*140
# Out:
# 19600

# %%
wholeInput
# Out:
# '...'

# %%
(141%140)
# Out:
# 1

# %%
(140%140)
# Out:
# 0

# %%
(139%140)
# Out:
# 139

# %%
(280%140)
# Out:
# 0

# %%
(281%140)
# Out:
# 1

# %%
(279%140)
# Out:
# 139

# %%
250%140
# Out:
# 110

# %%
0 - 1 -2 -- --- 139
140 ---    ---- 280
# Out:
# -140

# %%
import time

def diagonalize(data):
    diagonal = ["".join([data[i][j+i] for i in range(len(data)-j)]) for j in range(len(data))][-1::-1]
    diagonal += ["".join([data[j+i][i] for i in range(len(data)-j)]) for j in range(1,len(data))]
    return diagonal

def has_x(data, i, j):
    d1 = data[i-1][j-1] + data[i+1][j+1]
    d2 = data[i-1][j+1] + data[i+1][j-1]
    if (d1 == "MS" or d1 == "SM") and (d2 == "MS" or d2 == "SM"):
        return True
    return False

def part1(data):
    print(f"{len(data)}x{len(data[0])}")
    key = "XMAS"
    count = 0
    for line in data:
        count += line.count(key) + line[::-1].count(key)
    count1 = count
    print(count1)
    #Transpose word grid
    transpose = ["".join([line[x] for line in data]) for x in range(len(data[0]))]
    for line in transpose:
        count += line.count(key) + line[::-1].count(key)
    count2 = count - count1
    print(count2)
    #Create forward diagonal \
    diagonal = diagonalize(data)
    for line in diagonal:
        count += line.count(key) + line[::-1].count(key)
    count3 = count - count2
    print(count3)
    #Create backward diagonal /
    diagonal = diagonalize(data[::-1])
    for line in diagonal:
        count += line.count(key) + line[::-1].count(key)
    count4 = count - count3
    print(count4)
    return count

def part2(data):
    count = 0
    for i in range(1,len(data)-1):
        for j in range(1,len(data[0])-1):
            if data[i][j] == "A":
                if has_x(data, i, j):
                    count += 1
    return count

# with open("inputFile") as file:
with open("wak_input.txt") as file:
    data = file.read()
    data = data.splitlines()

start = time.perf_counter()
res1 = part1(data)
print(f"Part 1: {res1} -- {time.perf_counter()-start:.4f} s")
start = time.perf_counter()
res2 = part2(data)
print(f"Part 2: {res2} -- {time.perf_counter()-start:.4f} s")
# Out:
# 140x140
# 433
# 439
# 1282
# 1296
# Part 1: 2578 -- 0.0037 s
# Part 2: 1972 -- 0.0020 s
